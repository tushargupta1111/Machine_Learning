# %%
# Feature Engineering is the process of using domain knowledge to extract feature from raw data.
# These features can be used to improve the performance of ML Algorithm.

# %%
# Dataset --> Data Retrieval -->
# Data Preprocessing --> Featue Extraction & Engineering --> Fearture Scaling & Selection -->
# ML Algorithm --> Modeling --> Model Evaluation Tunning --> Deployment & Monitoring

# %%
# Feature Transformation
# Feature Construction
# Feature Selection
# Feature Extraction

# %%
# Feature Transformation
  # Handling Missing Values
  # Outliers Detection
  # Handling Categorical Features
  # Encoding Numerical Features
  # Feature Scaling

# %%
# Additional Transformation
  # Column Transformation
  # Sklearn Pipeline
  # Mathematical Transformation
  # Handling Mixed Data
